# %%
import pandas as pd
import IPython.display
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline  

df = pd.read_csv("/home/ziletti/Documents/calc_nomadml/rot_inv_3d/df_facets.csv")

# %%
df
# Out:
#                                            ase_db_file                                               cell                  checksum chemical_formula                                           filename  target        prob_0        prob_1        prob_2        prob_3        prob_4
# 0    /home/ziletti/Documents/calc_nomadml/rot_inv_3...  [[12.0, 0.0, 0.0], [0.0, 12.0, 0.0], [0.0, 0.0...    four_grains_poly_0_0_0              NaN  /home/ziletti/Documents/calc_nomadml/rot_inv_3...     NaN           NaN           NaN           NaN           NaN           NaN
# 1    /home/ziletti/Documents/calc_nomadml/rot_inv_3...  [[12.0, 0.0, 0.0], [0.0, 12.0, 0.0], [0.0, 0.0...   four_grains_poly_0_0_10              NaN  /home/ziletti/Documents/calc_nomadml/rot_inv_3...     NaN           NaN           NaN           NaN           NaN           NaN
# ...

# %%
df['checksum'][0]
# Out:
# 'four_grains_poly_0_0_0'

# %%
import os
# df['checksum'].tolist()
# df["nb_position_x"] = df["checksum"].apply(lambda x: int(os.path.splitext(os.path.basename(x))[0].split('_op0_target.json')[0].split('four_grains_poly_')[1].split('_')[2]))
# df["nb_position_y"] = df["checksum"].apply(lambda x: int(os.path.splitext(os.path.basename(x))[0].split('_op0_target.json')[0].split('four_grains_poly_')[1].split('_')[1]))
# df["nb_position_z"] = df["checksum"].apply(lambda x: int(os.path.splitext(os.path.basename(x))[0].split('_op0_target.json')[0].split('four_grains_poly_')[1].split('_')[0]))

# df["nb_position_x"] = df["checksum"].apply(lambda x: int(os.path.splitext(os.path.basename(x))[0].split('_op0_target.json')[0].split('screw_dislocations_4_')[1].split('_')[2]))
# df["nb_position_y"] = df["checksum"].apply(lambda x: int(os.path.splitext(os.path.basename(x))[0].split('_op0_target.json')[0].split('screw_dislocations_4_')[1].split('_')[1]))
# df["nb_position_z"] = df["checksum"].apply(lambda x: int(os.path.splitext(os.path.basename(x))[0].split('_op0_target.json')[0].split('screw_dislocations_4_')[1].split('_')[0]))

# df["nb_position_x"] = df["checksum"].apply(lambda x: int(os.path.splitext(os.path.basename(x))[0].split('_op0_target.json')[0].split('screw_dislocations_4_small_')[1].split('_')[2]))
# df["nb_position_y"] = df["checksum"].apply(lambda x: int(os.path.splitext(os.path.basename(x))[0].split('_op0_target.json')[0].split('screw_dislocations_4_small_')[1].split('_')[1]))
# df["nb_position_z"] = df["checksum"].apply(lambda x: int(os.path.splitext(os.path.basename(x))[0].split('_op0_target.json')[0].split('screw_dislocations_4_small_')[1].split('_')[0]))

df["nb_position_x"] = df["checksum"].apply(lambda x: int(os.path.splitext(os.path.basename(x))[0].split('_op0_target.json')[0].split('fcc_crystal_twinning_')[1].split('_')[2]))
df["nb_position_y"] = df["checksum"].apply(lambda x: int(os.path.splitext(os.path.basename(x))[0].split('_op0_target.json')[0].split('fcc_crystal_twinning_')[1].split('_')[1]))
df["nb_position_z"] = df["checksum"].apply(lambda x: int(os.path.splitext(os.path.basename(x))[0].split('_op0_target.json')[0].split('fcc_crystal_twinning_')[1].split('_')[0]))

# df["nb_position_x"] = df["checksum"].apply(lambda x: int(os.path.splitext(os.path.basename(x))[0].split('_op0_target.json')[0].split('edge_dislocation_small_')[1].split('_')[2]))
# df["nb_position_y"] = df["checksum"].apply(lambda x: int(os.path.splitext(os.path.basename(x))[0].split('_op0_target.json')[0].split('edge_dislocation_small_')[1].split('_')[1]))
# df["nb_position_z"] = df["checksum"].apply(lambda x: int(os.path.splitext(os.path.basename(x))[0].split('_op0_target.json')[0].split('edge_dislocation_small_')[1].split('_')[0]))

|
print df["nb_position_x"]
print df["nb_position_y"]
print df["nb_position_z"]


df = df.sort_values(['nb_position_z','nb_position_y', 'nb_position_x'], ascending=True)

# df = df.sort_values(by=["nb_position_x"]).reset_index()
# df = df.sort_index(by=["nb_position_y"]).reset_index()
# df = df.sort_index(by=["nb_position_z"]).reset_index()
pd.set_option('display.height', 1000)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)


# df
# Out:
#   File "<ipython-input-19-7fa71253b882>", line 23
#     |
#     ^
# SyntaxError: invalid syntax

# %%
#clustering_labels = df['clustering_labels'].values.reshape(11, 11)
max_n = (np.amax(df["nb_position_x"].values) + 1, np.amax(df["nb_position_y"].values)+1, np.amax(df["nb_position_z"].values)+1)
prob_bcc = df['prob_0'].values.reshape(max_n[1], max_n[0])
prob_diam = df['prob_1'].values.reshape(max_n[1], max_n[0])
prob_fcc = df['prob_2'].values.reshape(max_n[1], max_n[0])
prob_hex = df['prob_3'].values.reshape(max_n[1], max_n[0])
max_n

# %%
#plt.imshow(prob_bcc, interpolation='nearest', cmap="viridis")
#plt.imshow(prob_diam, interpolation='nearest', cmap="viridis")
#plt.imshow(prob_fcc, interpolation='nearest', cmap="viridis")
#plt.imshow(prob_hcp, interpolation='nearest', cmap="viridis")

#plt.imshow(clustering_labels, interpolation='nearest', cmap="viridis")

# %%
# row and column sharing
#f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharex='col', sharey='row')
#ax1.imshow(prob_bcc, interpolation='nearest', cmap="Reds", vmin=0.0, vmax=0.9)
#ax2.imshow(prob_diam, interpolation='nearest', cmap="Reds", vmin=0.0, vmax=0.9)
#ax3.imshow(prob_fcc, interpolation='nearest', cmap="Reds", vmin=0.0, vmax=0.9)
#ax4.imshow(prob_hcp, interpolation='nearest', cmap="Reds", vmin=0.0, vmax=0.9)

# %%
print prob_diam.shape

# %%
# Make plot with vertical (default) colorbar
from matplotlib import cm

# cmap=cm.afmhot
cmap='viridis'
#https://matplotlib.org/gallery/images_contours_and_fields/interpolation_methods.html
# interpolation='hanning'
# interpolation='sinc'
interpolation='none'


# fig, ax = plt.subplots()
# cax = ax.imshow(prob_bcc, interpolation=interpolation, cmap=cmap, vmin=0.0, vmax=1., origin='lower')
# ax.set_title('Classification probability (bcc)')
# plt.xlabel(u'x  [\u212B]')
# plt.ylabel(u'y [\u212B]')
# # Add colorbar, make sure to specify tick locations to match desired ticklabels
# cbar = fig.colorbar(cax)
# plt.savefig('/home/ziletti/Documents/calc_nomadml/rot_inv_3d/prob_bcc.png', format='png', dpi=1000)
# plt.show()

# fig, ax = plt.subplots()
# cax = ax.imshow(prob_diam, interpolation=interpolation, cmap=cmap, vmin=0., vmax=1., origin='lower')
# ax.set_title('Classification probability (diam)')
# plt.xlabel(u'x  [\u212B]')
# plt.ylabel(u'y [\u212B]')
# # Add colorbar, make sure to specify tick locations to match desired ticklabels
# cbar = fig.colorbar(cax)
# plt.savefig('/home/ziletti/Documents/calc_nomadml/rot_inv_3d/prob_diam.png', format='png', dpi=1000)
# plt.show()

fig, ax = plt.subplots()
cax = ax.imshow(prob_fcc, interpolation=interpolation, cmap=cmap, vmin=0.9999, vmax=1., origin='lower')
ax.set_title('Classification probability (fcc)')
plt.xlabel(u'x  [\u212B]')
plt.ylabel(u'y [\u212B]')
# Add colorbar, make sure to specify tick locations to match desired ticklabels
cbar = fig.colorbar(cax)
plt.savefig('/home/ziletti/Documents/calc_nomadml/rot_inv_3d/prob_fcc.png', format='png', dpi=1000)
plt.show()

# fig, ax = plt.subplots()
# cax = ax.imshow(prob_hex, interpolation=interpolation, cmap=cmap, vmin=0., vmax=1., origin='lower')
# ax.set_title('Classification probability (hex)')
# plt.xlabel(u'x  [\u212B]')
# plt.ylabel(u'y [\u212B]')
# # Add colorbar, make sure to specify tick locations to match desired ticklabels
# cbar = fig.colorbar(cax)
# plt.savefig('/home/ziletti/Documents/calc_nomadml/rot_inv_3d/prob_hcp.png', format='png', dpi=1000)
# plt.show()
